# %% [markdown]
# # Pre-processing the data

# %% [markdown]
# Example Running:
# ```
# python pre_CT_MR.py CT Anorectum /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/nnUNet_raw/Dataset001_Anorectum/imagesTr /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/nnUNet_raw/Dataset001_Anorectum/labelsTr /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed --axis 0 --verbose
# ```

# %%
# pip install connected-components-3d
import numpy as np

# import nibabel as nib
import SimpleITK as sitk
import os

join = os.path.join
from skimage import transform
from tqdm import tqdm
import cc3d

import argparse

import SimpleITK as sitk
import matplotlib.pyplot as plt

# %%
parser = argparse.ArgumentParser(description="Preprocess CT/MR images")
parser.add_argument('modality', type=str, help='modality of the images, CT or MR')
parser.add_argument('anatomy', type=str, help='anatomy of the images')
parser.add_argument('nii_path', type=str, help='path to the nii images')
parser.add_argument('gt_path', type=str, help='path to the ground truth')
parser.add_argument('npy_path', type=str, help='path to save the npy files')
parser.add_argument('--img_name_suffix', type=str, default='_0000.nii.gz', help='suffix of the image name')
parser.add_argument('--gt_name_suffix', type=str, default='.nii.gz', help='suffix of the ground truth name')
parser.add_argument('--image_size', type=int, default=1024, help='size of the images')
parser.add_argument('--voxel_num_thre2d', type=int, default=100, help='threshold of the number of voxels in 2D')
parser.add_argument('--voxel_num_thre3d', type=int, default=1000, help='threshold of the number of voxels in 3D')
parser.add_argument('--WINDOW_LEVEL', type=int, default=40, help='window level for CT images')
parser.add_argument('--WINDOW_WIDTH', type=int, default=400, help='window width for CT images')
parser.add_argument('--axis', type=int, default=0, help='along which axis to preprocess image')
parser.add_argument('--verbose', action='store_true', help='print more information', default=False)
# Out:
# _StoreTrueAction(option_strings=['--verbose'], dest='verbose', nargs=0, const=True, default=False, type=None, choices=None, required=False, help='print more information', metavar=None)

# %%
# import sys
# original_args = sys.argv

# # sys.argv = [
# #     sys.argv[0],
# #     'CT',
# #     'Bladder',
# #     '/vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/nnUNet_raw/Dataset002_Bladder/imagesTr',
# #     '/vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/nnUNet_raw/Dataset002_Bladder/labelsTr',
# #     '/vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed',
# #     '--axis', '1', '--verbose'
# # ]

# %%
args = parser.parse_args()

if args.verbose:
    for arg in vars(args):
        print(f"{arg}: {getattr(args, arg)}")
# Out:
# modality: CT
# anatomy: Bladder
# nii_path: /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/nnUNet_raw/Dataset002_Bladder/imagesTr
# gt_path: /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/nnUNet_raw/Dataset002_Bladder/labelsTr
# npy_path: /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed
# img_name_suffix: _0000.nii.gz
# gt_name_suffix: .nii.gz
# image_size: 1024
# voxel_num_thre2d: 100
# voxel_num_thre3d: 1000
# WINDOW_LEVEL: 40
# WINDOW_WIDTH: 400
# axis: 1
# verbose: True

# %%
modality = args.modality
assert modality in ["CT", "MR"]
anatomy = args.anatomy

img_name_suffix = args.img_name_suffix
gt_name_suffix = args.gt_name_suffix
prefix = modality + "_" + anatomy + "_"

nii_path = args.nii_path  # path to the nii images
gt_path = args.gt_path  # path to the ground truth
npy_path = args.npy_path

gt_save_dir = join(npy_path, "gts", anatomy, f'axis{str(args.axis)}')
img_save_dir = join(npy_path, "imgs", f'axis{str(args.axis)}')

os.makedirs(gt_save_dir, exist_ok=True)
os.makedirs(img_save_dir, exist_ok=True)

image_size = args.image_size
voxel_num_thre2d = args.voxel_num_thre2d
voxel_num_thre3d = args.voxel_num_thre3d

names = sorted(os.listdir(gt_path))

# set window level and width
# https://radiopaedia.org/articles/windowing-ct
WINDOW_LEVEL = args.WINDOW_LEVEL  # only for CT images
WINDOW_WIDTH = args.WINDOW_WIDTH  # only for CT images

# %%
def slice_at(i):
    slices = [slice(None)] * 3
    slices[args.axis] = i
    return tuple(slices)

# %%
# save preprocessed images and masks as npz files
for name in tqdm(names):

    if args.verbose:
        print(f'processing name {name}')

    image_name = name.split(gt_name_suffix)[0] + img_name_suffix
    gt_name = name
    gt_sitk = sitk.ReadImage(join(gt_path, gt_name))
    gt_data_ori = np.uint8(sitk.GetArrayFromImage(gt_sitk))

    if args.verbose:
        print('dusting images')

    # exclude the objects with less than 1000 pixels in 3D
    gt_data_ori = cc3d.dust(
        gt_data_ori, threshold=voxel_num_thre3d, connectivity=26, in_place=True
    )

    if args.verbose:
        print('gt_data_ori.shape', gt_data_ori.shape)

    # remove small objects with less than 100 pixels in 2D slices
    for slice_i in range(gt_data_ori.shape[args.axis]):
        slices = slice_at(slice_i)
        gt_i = gt_data_ori[slices]
        # remove small objects with less than 100 pixels
        # reason: for such small objects, the main challenge is detection rather than segmentation
        gt_data_ori[slices] = cc3d.dust(
            gt_i, threshold=voxel_num_thre2d, connectivity=8, in_place=True
        )
        
    if args.verbose:
        print('finding non-zero slices')

    # find non-zero slices
    # For some reason vectorizing this operation doesn't work.
    slice_index = []
    for i in range(gt_data_ori.shape[args.axis]):
        my_slice = gt_data_ori[slice_at(i)]
        if np.any(my_slice):
            slice_index.append(i)

    if args.verbose:
        print(f'for name {name} the non zero slices for axis {args.axis} are {slice_index}')

    if len(slice_index) > 0:
        # crop the ground truth with non-zero slices
        gt_roi = gt_data_ori[slice_at(slice_index)]
        # load image and preprocess
        img_sitk = sitk.ReadImage(join(nii_path, image_name))
        image_data = sitk.GetArrayFromImage(img_sitk)
        # nii preprocess start
        if modality == "CT":
            if args.verbose:
                print('normalizing Hosfield units')
            lower_bound = WINDOW_LEVEL - WINDOW_WIDTH / 2
            upper_bound = WINDOW_LEVEL + WINDOW_WIDTH / 2
            image_data_pre = np.clip(image_data, lower_bound, upper_bound)
            image_data_pre = (
                (image_data_pre - np.min(image_data_pre))
                / (np.max(image_data_pre) - np.min(image_data_pre))
                * 255.0
            )
        else:
            raise NotImplementedError(f"modality {modality} is not implemented yet")

        if args.verbose:
            print('Saving slices...')

        image_data_pre = np.uint8(image_data_pre)
        img_roi = image_data_pre[slice_at(slice_index)]

        # np.savez_compressed(join(npy_path, prefix + gt_name.split(gt_name_suffix)[0]+'.npz'), imgs=img_roi, gts=gt_roi, spacing=img_sitk.GetSpacing())
        # # save the image and ground truth as nii files for sanity check;
        # # they can be removed
        # img_roi_sitk = sitk.GetImageFromArray(img_roi)
        # gt_roi_sitk = sitk.GetImageFromArray(gt_roi)
        # sitk.WriteImage(
        #     img_roi_sitk,
        #     join(npy_path, prefix + gt_name.split(gt_name_suffix)[0] + "_img.nii.gz"),
        # )
        # sitk.WriteImage(
        #     gt_roi_sitk,
        #     join(npy_path, prefix + gt_name.split(gt_name_suffix)[0] + "_gt.nii.gz"),
        # )
        # save the each CT image as npy file
        for i, original_slice in zip(range(img_roi.shape[args.axis]), slice_index):
            img_save_path = join(
                    img_save_dir,
                    modality + "_"
                    + gt_name.split(gt_name_suffix)[0]
                    + "-"
                    + str(original_slice).zfill(3)
                    + ".npy",
                )

            gt_save_path =  join(
                    gt_save_dir,
                    prefix
                    + gt_name.split(gt_name_suffix)[0]
                    + "-"
                    + str(original_slice).zfill(3)
                    + ".npy",
                )
            
            if not os.path.isfile(img_save_path):
                img_i = img_roi[slice_at(i)]
                img_3c = np.repeat(img_i[:, :, None], 3, axis=-1)
                resize_img_skimg = transform.resize(
                    img_3c,
                    (image_size, image_size),
                    order=3,
                    preserve_range=True,
                    mode="constant",
                    anti_aliasing=True,
                )
                resize_img_skimg_01 = (resize_img_skimg - resize_img_skimg.min()) / np.clip(
                    resize_img_skimg.max() - resize_img_skimg.min(), a_min=1e-8, a_max=None
                )  # normalize to [0, 1], (H, W, 3)
                np.save(img_save_path, resize_img_skimg_01)
            elif args.verbose:
                print('file already found at ', img_save_path)
            

            if not os.path.isfile(gt_save_path):
                gt_i = gt_roi[slice_at(i)]
                resize_gt_skimg = transform.resize(
                    gt_i,
                    (image_size, image_size),
                    order=0,
                    preserve_range=True,
                    mode="constant",
                    anti_aliasing=False,
                )
                resize_gt_skimg = np.uint8(resize_gt_skimg)
                # assert resize_img_skimg_01.shape[:2] == resize_gt_skimg.shape

                np.save(gt_save_path, resize_gt_skimg)
            elif args.verbose:
                print('file already found at ', gt_save_path)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# processing name zzAMLART_001.nii.gz
# dusting images
# gt_data_ori.shape (297, 512, 512)
# finding non-zero slices
# for name zzAMLART_001.nii.gz the non zero slices for axis 1 are [195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278]
# normalizing Hosfield units
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-195.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-196.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-197.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-198.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-199.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-200.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-201.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-202.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-203.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-204.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-205.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-206.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-207.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-208.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-209.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-210.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-211.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-212.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-213.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-214.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-215.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-216.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-217.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-218.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-219.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-220.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-221.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-222.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-223.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-224.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-225.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-226.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-227.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-228.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-229.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-230.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-231.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_001-232.npy
#   1%|          | 1/100 [01:32<2:33:25, 92.98s/it]
# processing name zzAMLART_002.nii.gz
# dusting images
# gt_data_ori.shape (267, 512, 512)
# finding non-zero slices
# for name zzAMLART_002.nii.gz the non zero slices for axis 1 are [188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252]
# normalizing Hosfield units
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_002-188.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_002-189.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_002-190.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_002-191.npy
#   2%|▏         | 2/100 [03:35<2:59:50, 110.11s/it]
# processing name zzAMLART_003.nii.gz
# dusting images
# gt_data_ori.shape (225, 512, 512)
# finding non-zero slices
# for name zzAMLART_003.nii.gz the non zero slices for axis 1 are [184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256]
# normalizing Hosfield units
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-184.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-185.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-186.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-187.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-188.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-189.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-190.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-191.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-192.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-193.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-194.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-195.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-196.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-197.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-198.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-199.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-200.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-201.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_003-202.npy
#   3%|▎         | 3/100 [05:23<2:56:37, 109.25s/it]
# processing name zzAMLART_004.nii.gz
# dusting images
# gt_data_ori.shape (219, 512, 512)
# finding non-zero slices
# for name zzAMLART_004.nii.gz the non zero slices for axis 1 are [186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275]
# normalizing Hosfield units
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-186.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-187.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-188.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-189.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-190.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-191.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-192.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-193.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-194.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-195.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-196.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-197.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-198.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-199.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-200.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-201.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-202.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-203.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-204.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-205.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-206.npy
# file already found at  /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/data/MedSAM_preprocessed/imgs/axis1/CT_zzAMLART_004-207.npy
#   3%|▎         | 3/100 [06:36<3:33:52, 132.29s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 107
#     105 img_i = img_roi[slice_at(i)]
#     106 img_3c = np.repeat(img_i[:, :, None], 3, axis=-1)
# --> 107 resize_img_skimg = transform.resize(
#     108     img_3c,
#     109     (image_size, image_size),
#     110     order=3,
#     111     preserve_range=True,
#     112     mode="constant",
#     113     anti_aliasing=True,
#     114 )
#     115 resize_img_skimg_01 = (resize_img_skimg - resize_img_skimg.min()) / np.clip(
#     116     resize_img_skimg.max() - resize_img_skimg.min(), a_min=1e-8, a_max=None
#     117 )  # normalize to [0, 1], (H, W, 3)
#     118 np.save(img_save_path, resize_img_skimg_01)
#
# File /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/.venv/lib/python3.10/site-packages/skimage/transform/_warps.py:203, in resize(image, output_shape, order, mode, cval, clip, preserve_range, anti_aliasing, anti_aliasing_sigma)
#     200     filtered = image
#     202 zoom_factors = [1 / f for f in factors]
# --> 203 out = ndi.zoom(
#     204     filtered, zoom_factors, order=order, mode=ndi_mode, cval=cval, grid_mode=True
#     205 )
#     207 _clip_warp_output(image, out, mode, cval, clip)
#     209 return out
#
# File /vol/biomedic3/bglocker/ugproj2324/az620/radiotherapy/.venv/lib/python3.10/site-packages/scipy/ndimage/_interpolation.py:869, in zoom(input, zoom, output, order, mode, cval, prefilter, grid_mode)
#     865 zoom = numpy.divide(zoom_nominator, zoom_div,
#     866                     out=numpy.ones_like(input.shape, dtype=numpy.float64),
#     867                     where=zoom_div != 0)
#     868 zoom = numpy.ascontiguousarray(zoom)
# --> 869 _nd_image.zoom_shift(filtered, zoom, None, output, order, mode, cval, npad,
#     870                      grid_mode)
#     871 return output
#
# KeyboardInterrupt:
