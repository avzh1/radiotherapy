# %% [markdown]
# # Run inference on the nnUNet Model we have fine-tuned
#
# Assuming that the pre-processed data is available, and the model has been trained for a
# fold

# %%
import os 
import subprocess

def setup_data_vars(mine = True, overwrite = True):
    """
    From within any directory related to radiotherapy with backtrack into the data folder
    and execute the data_vars script. The assumption is that the datavars script will
    output the list of environment variables that need to be set. This function will set
    the environment variables for the current session.

    For the mean while, my model hasn't completely finished training, therefore, to get
    this task done, I will use Ben's pretrained nnUNet and then once mine has finished
    training I will use my own. For the mean while, this means that we can choose between
    using Ben's pretrained model or my own.
    """

    # If the environment variables are not set, assume that either a custom one has been
    # provided or resetting them again is a redundant task
    if os.environ.get('nnUNet_raw') is None or overwrite is True:
        # run the script in the data folder for specifying the environment variables
        if mine:
            cwd = os.getcwd().split('/')
            data_dir = os.path.join('/'.join(cwd[:cwd.index('radiotherapy') + 1]), 'data')

            # Assuming the data_vars.sh script echoes the environment variables
            script = os.path.join(data_dir, 'data_vars.sh')
            output = subprocess.run([script], capture_output=True)
            
            assert len(output.stdout) != 0, f"Please check {script} and make sure it echoes \
    the environment variables."

            output = output.stdout.decode('utf-8')
        else:
            data_dir = '/vol/biomedic3/bglocker/nnUNet'

            # Assuming this script won't change, it contains hard coded exports
            script = os.path.join(data_dir, 'exports')

            with open(script, 'r') as file:
                output = file.read()
        
        for line in output.split('\n'):
            if line != '':
                if mine:
                    line = line.split(': ')
                    os.environ[line[0]] = line[1]
                else:
                    line = line.split('=')
                    os.environ[line[0].split(' ')[1]] = line[1]

    assert os.environ.get('nnUNet_raw') is not None, "Environemnt variables not set. \
Please run the data_vars.sh script in the data folder."

# %%
def get_raw_and_gt_data_paths():
    
    setup_data_vars()

    classes = [os.environ.get('data_Anorectum'), 
        os.environ.get('data_Bladder'), 
        os.environ.get('data_CTVn'), 
        os.environ.get('data_CTVp'), 
        os.environ.get('data_Parametrium'), 
        os.environ.get('data_Uterus'), 
        os.environ.get('data_Vagina')]

    raw_data = [os.path.join(os.environ.get('nnUNet_raw'), x, os.environ.get('data_trainingImages')) for x in classes]
    gt_labels = [os.path.join(os.environ.get('nnUNet_raw'), x, os.environ.get('data_trainingLabels')) for x in classes]

    return classes, raw_data, gt_labels

# %%
def initialise_predictor(model_path, fold, device):

    from nnunetv2.inference.predict_from_raw_data import nnUNetPredictor
    import torch

    predictor = nnUNetPredictor(
            tile_step_size=0.5,
            use_gaussian=True,
            use_mirroring=True,
            perform_everything_on_device=True,
            device=device,
            verbose=False,
            verbose_preprocessing=False,
            allow_tqdm=True
        )

    predictor.initialize_from_trained_model_folder(
        model_path,
        use_folds=fold,
        checkpoint_name='checkpoint_final.pth',
    )

    return predictor

# %%
import sys
import torch
import argparse
import multiprocessing


if __name__ == '__main__':
    multiprocessing.freeze_support()

    if torch.cuda.is_available():
        device = torch.device('cuda')
    else:
        device = torch.device('cpu')   

    setup_data_vars()
    classes, raw_data, gt_labels = get_raw_and_gt_data_paths()

    print('[DEBUG]: Obtained the environment variables. These are:')
    print(f'nnUNet_raw: {os.environ.get("nnUNet_raw")}')
    print(f'nnUNet_preprocessed: {os.environ.get("nnUNet_preprocessed")}')
    print(f'nnUNet_results: {os.environ.get("nnUNet_results")}')

    parser = argparse.ArgumentParser()
    parser.add_argument('dataset', type=int, help='The dataset to run inference on')
    parser.add_argument('fold', type=int, help='The max number of nodes that were trained')
    sys.argv = ['2_inference.py', '1', '0']
    args = parser.parse_args()
    
    assert args.dataset is not None, "Please provide the dataset to fine tune on"
    assert args.dataset in range(1, len(classes) + 1), "Please provide a valid dataset to fine tune on"

    assert args.fold is not None, "Please provide the fold to run inference on"
    assert args.fold in range(5), "Please provide a valid fold to run inference on"

    TARGET_DATASET = args.dataset
    FOLD = tuple(range(0, args.fold + 1))
    CONFIG = '3d_fullres'

    TARGET_DATASET = 2
    FOLD = tuple(range(0, 0 + 1))

    # Run inference
    model_name = 'nnUNetTrainer_50epochs__totseg_nnUNetPlans__3d_fullres'
    input_file = os.path.join(os.environ.get('nnUNet_raw'), classes[TARGET_DATASET - 1], os.environ.get('data_trainingImages'))
    model_path = os.path.join(os.environ.get('nnUNet_results'), classes[TARGET_DATASET - 1], model_name) 
    output_file = os.path.join(os.environ.get('nnUNet_raw'), '..', 'TotalSegmentator_inference', classes[TARGET_DATASET - 1], model_name)

    print('I am predicting on the dataset:', classes[TARGET_DATASET - 1])
    print('The Fold is:', FOLD)
    print('The config I\'m using is:', CONFIG)
    print('The model path is:', model_path)
    print('The input file is:', input_file)
    print('The output file is:', output_file)

    predictor = initialise_predictor(model_path, FOLD, device)
    predictor.predict_from_files(input_file,
                                 output_file,
                                 save_probabilities=False, overwrite=False,
                                 num_processes_preprocessing=2, num_processes_segmentation_export=2,
                                 folder_with_segs_from_prev_stage=None, num_parts=1, part_id=0)
# Out:
# [DEBUG]: Obtained the environment variables. These are:
# nnUNet_raw: /vol/bitbucket/az620/radiotherapy/data/nnUNet_raw
# nnUNet_preprocessed: /vol/bitbucket/az620/radiotherapy/data/nnUNet_preprocessed
# nnUNet_results: /vol/bitbucket/az620/radiotherapy/data/nnUNet_results
# /vol/bitbucket/az620/radiotherapy/models/nnUNet/nnunetv2/utilities/plans_handling/plans_handler.py:37: UserWarning: Detected old nnU-Net plans format. Attempting to reconstruct network architecture parameters. If this fails, rerun nnUNetv2_plan_experiment for your dataset. If you use a custom architecture, please downgrade nnU-Net to the version you implemented this or update your implementation + plans.
#   warnings.warn("Detected old nnU-Net plans format. Attempting to reconstruct network architecture "
# There are 100 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 100 cases that I would like to predict
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 100 cases.
#
# Predicting zzAMLART_001:
# perform_everything_on_device: True
#  43%|████▎     | 65/150 [00:20<00:26,  3.16it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 49
#      46 output_file = os.path.join(os.environ.get('nnUNet_raw'), '..', 'TotalSegmentator_inference', classes[TARGET_DATASET - 1], model_name)
#      48 predictor = initialise_predictor(model_path, FOLD, device)
# ---> 49 predictor.predict_from_files(input_file,
#      50                              output_file,
#      51                              save_probabilities=False, overwrite=False,
#      52                              num_processes_preprocessing=2, num_processes_segmentation_export=2,
#      53                              folder_with_segs_from_prev_stage=None, num_parts=1, part_id=0)
#
# File /vol/bitbucket/az620/radiotherapy/models/nnUNet/nnunetv2/inference/predict_from_raw_data.py:256, in nnUNetPredictor.predict_from_files(self, list_of_lists_or_source_folder, output_folder_or_list_of_truncated_output_files, save_probabilities, overwrite, num_processes_preprocessing, num_processes_segmentation_export, folder_with_segs_from_prev_stage, num_parts, part_id)
#     250     return
#     252 data_iterator = self._internal_get_data_iterator_from_lists_of_filenames(list_of_lists_or_source_folder,
#     253                                                                          seg_from_prev_stage_files,
#     254                                                                          output_filename_truncated,
#     255                                                                          num_processes_preprocessing)
# --> 256 return self.predict_from_data_iterator(data_iterator, save_probabilities, num_processes_segmentation_export)
#
# File /vol/bitbucket/az620/radiotherapy/models/nnUNet/nnunetv2/inference/predict_from_raw_data.py:373, in nnUNetPredictor.predict_from_data_iterator(self, data_iterator, save_probabilities, num_processes_segmentation_export)
#     370     sleep(0.1)
#     371     proceed = not check_workers_alive_and_busy(export_pool, worker_list, r, allowed_num_queued=2)
# --> 373 prediction = self.predict_logits_from_preprocessed_data(data).cpu()
#     375 if ofile is not None:
#     376     # this needs to go into background processes
#     377     # export_prediction_from_logits(prediction, properties, self.configuration_manager, self.plans_manager,
#     378     #                               self.dataset_json, ofile, save_probabilities)
#     379     print('sending off prediction to background worker for resampling and export')
#
# File /vol/bitbucket/az620/radiotherapy/models/nnUNet/nnunetv2/inference/predict_from_raw_data.py:491, in nnUNetPredictor.predict_logits_from_preprocessed_data(self, data)
#     487 # why not leave prediction on device if perform_everything_on_device? Because this may cause the
#     488 # second iteration to crash due to OOM. Grabbing that with try except cause way more bloated code than
#     489 # this actually saves computation time
#     490 if prediction is None:
# --> 491     prediction = self.predict_sliding_window_return_logits(data).to('cpu')
#     492 else:
#     493     prediction += self.predict_sliding_window_return_logits(data).to('cpu')
#
# File /vol/bitbucket/az620/radiotherapy/models/nnUNet/nnunetv2/inference/predict_from_raw_data.py:638, in nnUNetPredictor.predict_sliding_window_return_logits(self, input_image)
#     635 if self.perform_everything_on_device and self.device != 'cpu':
#     636     # we need to try except here because we can run OOM in which case we need to fall back to CPU as a results device
#     637     try:
# --> 638         predicted_logits = self._internal_predict_sliding_window_return_logits(data, slicers,
#     639                                                                                self.perform_everything_on_device)
#     640     except RuntimeError:
#     641         print(
#     642             'Prediction on device was unsuccessful, probably due to a lack of memory. Moving results arrays to CPU')
#
# File /vol/bitbucket/az620/radiotherapy/models/nnUNet/nnunetv2/inference/predict_from_raw_data.py:588, in nnUNetPredictor._internal_predict_sliding_window_return_logits(self, data, slicers, do_on_device)
#     585 workon = data[sl][None]
#     586 workon = workon.to(self.device, non_blocking=False)
# --> 588 prediction = self._internal_maybe_mirror_and_predict(workon)[0].to(results_device)
#     590 predicted_logits[sl] += (prediction * gaussian if self.use_gaussian else prediction)
#     591 n_predictions[sl[1:]] += (gaussian if self.use_gaussian else 1)
#
# File /vol/bitbucket/az620/radiotherapy/models/nnUNet/nnunetv2/inference/predict_from_raw_data.py:550, in nnUNetPredictor._internal_maybe_mirror_and_predict(self, x)
#     546     axes_combinations = [
#     547         c for i in range(len(mirror_axes)) for c in itertools.combinations([m + 2 for m in mirror_axes], i + 1)
#     548     ]
#     549     for axes in axes_combinations:
# --> 550         prediction += torch.flip(self.network(torch.flip(x, (*axes,))), (*axes,))
#     551     prediction /= (len(axes_combinations) + 1)
#     552 return prediction
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/dynamic_network_architectures/architectures/unet.py:62, in PlainConvUNet.forward(self, x)
#      60 def forward(self, x):
#      61     skips = self.encoder(x)
# ---> 62     return self.decoder(skips)
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/dynamic_network_architectures/building_blocks/unet_decoder.py:111, in UNetDecoder.forward(self, skips)
#     109 x = self.transpconvs[s](lres_input)
#     110 x = torch.cat((x, skips[-(s+2)]), 1)
# --> 111 x = self.stages[s](x)
#     112 if self.deep_supervision:
#     113     seg_outputs.append(self.seg_layers[s](x))
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/dynamic_network_architectures/building_blocks/simple_conv_blocks.py:137, in StackedConvBlocks.forward(self, x)
#     136 def forward(self, x):
# --> 137     return self.convs(x)
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/dynamic_network_architectures/building_blocks/simple_conv_blocks.py:71, in ConvDropoutNormReLU.forward(self, x)
#      70 def forward(self, x):
# ---> 71     return self.all_modules(x)
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:610, in Conv3d.forward(self, input)
#     609 def forward(self, input: Tensor) -> Tensor:
# --> 610     return self._conv_forward(input, self.weight, self.bias)
#
# File /vol/bitbucket/az620/radiotherapy/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:605, in Conv3d._conv_forward(self, input, weight, bias)
#     593 if self.padding_mode != "zeros":
#     594     return F.conv3d(
#     595         F.pad(
#     596             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     603         self.groups,
#     604     )
# --> 605 return F.conv3d(
#     606     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     607 )
#
# KeyboardInterrupt:
